# %%
import os
import string

vrm = []

for file in os.listdir():
    if file.endswith(".ttl"):
        vrm.append(file)

#lijst van alle afzonderlijke turtle files in de folder
print(vrm)
# Out:
# ['0_prefixes.ttl', 'ageAtDiagnosis.ttl', 'alcoholUseHistory.ttl', 'birthYear.ttl', 'bodyHeight.ttl', 'bodyWeight.ttl', 'educationLevel.ttl', 'neoplasmDiagnosis.ttl', 'patient.ttl', 'planningComparison.ttl', 'previousneoplasm.ttl', 'relationshipStatus.ttl', 'sex.ttl', 'smokingStatus.ttl', 'treatingCentre.ttl']

# %%
lines = []

for i in vrm:
    lines.append([line.rstrip('\n') for line in open("./%s" % (i))])

    #alles op 1 regel

print(lines[1])
# Out:
# ['', '###########################################', '# Add age at diagnosis ', '###########################################    ', 'map:ageAtDiagnosisQuery a rr:LogicalTable;', '    rr:sqlQuery """SELECT GEN_IDNUMBER as id, GEN_AGE as age FROM PBDWHackathon2018;""";', '    rdfs:label "";', '    skos:definition "".', '    ', 'map:ageAtDiagnosis a rr:TriplesMap;', '    rr:logicalTable map:ageAtDiagnosisQuery;', '    rr:subjectMap [', '        rr:template "patient/{id}/ageAtDiagnosis/{age}";', '        rr:class roo:C100002; #age_at_diagnosis', '    ];', '    rr:predicateObjectMap [', '        rr:predicate roo:P100042;  #has_value', '        rr:objectMap [', '            rr:column "age"; ', '            rr:datatype xsd:integer;', '        ];', '    ];                                                            ', '    rr:predicateObjectMap [', '        rr:predicate roo:P100029; #is_diagnosed_with', '        rr:objectMap [', '            rr:parentTriplesMap map:neoplasm;', '            rr:joinCondition [', '                rr:child "id";', '                rr:parent "id";', '            ];', '        ];', '    ]. ', '', 'map:neoplasm a rr:TriplesMap;', '    rr:logicalTable map:ageAtDiagnosisQuery;    ', '    rr:subjectMap [', '        rr:template "patient/{id}/neoplasm";', '        rr:class ncit:C3262; #neoplasm', '    ].', '', 'map:patient rr:predicateObjectMap [', '        rr:predicate roo:P100016; #has_age_at_diagnosis', '        rr:objectMap [', '            rr:parentTriplesMap map:ageAtDiagnosis;', '            rr:joinCondition [', '                rr:child "id";', '                rr:parent "id";', '            ];', '        ];', '    ].', '    ']

# %%
from more_itertools import locate
import re

for i in lines[1:]:
    #skip first element which is the prefixes file
    
    text = " ".join(i)  
    words = text.split()
    #all words as separate items in the list
    
    indices = list(locate(words, lambda x: x == 'rr:column'))
    #localise the column name with rr:column in the list "words"
    
    print("\n" + i[1] + "\n" + i[2] + "\n" + i[3])
    #add the name of the turtlefile and separate the column names
    
    for j in indices:
        columnNames = words[j+1].translate(str.maketrans('', '', string.punctuation))
        print(columnNames)
        #print de kolomnaam 
    
    #classes = list(locate(words, lambda x: x == 'rr:class'))
    #localise the class name with rr:class in the list "words"
    
    #for k in classes:
        #classNames = words[k+1] + " " + words[k+2].translate(str.maketrans('', '', string.punctuation))
        #print(classNames)
        ##print de kolomnaam   
    
  




    #different methods
    #pattern = re.compile("ncit")
    #for i in words:
        #if pattern.search(i):
            #print(i)
            ##print NCIT code
            
    #pattern2 = re.compile("roo:")
    #for i in words:
        #if pattern2.search(i):
            #print(i)
            ##print ROO code
# Out:
# ###########################################
# # Add age at diagnosis
# ###########################################
# age
# roo:C100002; ageatdiagnosis
# ncit:C3262; neoplasm
#
# ###########################################
# # Add alcohol use history
# ###########################################
# alcoholusehistory
# dayswithmorethan1glass
# numberofglasses
# ncit:C81229; alcohol
# roo:daysWithMoreThan1Glass; new
# roo:numberOfGlasses; new
#
# ###########################################
# # Add birth year
# ###########################################
# birthyear
# ncit:C25155; birth
#
# ###########################################
# # Add bodyheight
# ###########################################
# bodyheight
# ncit:C94488; stature
# uo:0000015; centimeter
#
# ###########################################
# # Add bodyweight
# ###########################################
# bodyweight
# ncit:C81328; bodyweight
# uo:0000009; kilogram
#
# ###########################################
# # Add educationlevel
# ###########################################
# educationlevel
# ncit:C17953; education
#
# ###########################################
# # Add neoplasm diagnosis
# ###########################################
# dateoffirstdiagnosis
# tumoursite
# radiotherapytreatmenttechnique
# ncit:C3262; neoplasm
# roo:dateOfFirstDiagnosis; new
# ncit:C3263; neoplasm
# ncit:C15313; radiation
#
# ###########################################
# # Add patient
# ###########################################
# id
# ncit:C16960; patient
# ncit:C25364; identifier
#
# ###########################################
# # Add planning comparison
# ###########################################
# planningcomparisonyesno
# planningcomparisondate
# planningcomparisonversion
# planningcomparisonoutcome
# protontherapy
# reasonnegativeprotontherapywithpositivedss
# ncit:C15313; radiation
# roo:planningComparison; new
# roo:PlanningComparisonDate; new
# roo:PlanningComparisonVersion; new
# roo:planningComparisonOutcome; new
# ncit:C66897; proton
# roo:reasonNegativeProtonTherapyWithPositivePlanningComparison; new
#
# ##########################################
# # Add previous neoplasm  Needs neoplasm
# ##########################################
# previousneoplasm
# tumoursite
# yearofdiagnosis
# previousradiotherapy
# reirradiation
# roo:personalHistoryOfMalignantNeoplasm; new
# ncit:C3263; neoplasm
# roo:dateOfDiagnosis; new
# roo:previousRadiotherapy; new
# roo:reirradiation; new
#
# ###########################################
# # Add relationship status
# ###########################################
# relationshipstatus
# ncit:C25188; marital
#
# ###########################################
# # Add biological Sex
# ###########################################
# sex
# ncit:C28421; sex
#
# ###########################################
# # Add smoking status
# ###########################################
# smokingstatus
# packyears
# timestoppedsmoking
# packyears
# ncit:C19796; smoking
# ncit:C67148; former
# roo:timeStoppedSmoking;
# ncit:C67147;
# ncit:C73993; pack
# uo:0000035; month
#
# ###########################################
# # Add treating centre
# ###########################################
# treatingcentre
# registrationdate
# referringcentre
# ncit:C19326; clinics
# ncit:C25646; registration
# ncit:C19326; clinics
